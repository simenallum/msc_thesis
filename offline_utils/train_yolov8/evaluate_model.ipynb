# %% [markdown]
# # Evaluate

# %%
from ultralytics import YOLO

model = YOLO("/home/msccomputer/catkin_ws/src/msc_thesis/offline_utils/train_yolov8/platform_detection/SGD_full_dataset/weights/best.pt")
# It'll use the data yaml file in model.pt if you don't set data.
# model.val()
# or you can set the data you want to val
model.val(data="/home/msccomputer/catkin_ws/src/msc_thesis/offline_utils/train_yolov8/Platform-3/data.yaml", imgsz=1280, iou=0.1, device=0, plots=True, batch=1, split='test')
# Out:
# Ultralytics YOLOv8.0.36 🚀 Python-3.8.10 torch-1.13.1+cu117 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 7982MiB)
# YOLOv8n summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /home/msccomputer/catkin_ws/src/msc_thesis/offline_utils/train_yolov8/Platform-3/test/labels.cache... 206 images, 8 backgrounds, 0 corrupt: 100%|██████████| 206/206 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 206/206 [00:04<00:00, 45.26it/s]
#                    all        206        198          1          1      0.995       0.97
# Speed: 0.6ms pre-process, 7.6ms inference, 0.0ms loss, 0.8ms post-process per image

# %% [markdown]
# # Predict on images

# %%
from ultralytics import YOLO
from PIL import Image
import cv2

model = YOLO("/home/msccomputer/catkin_ws/src/msc_thesis/offline_utils/train_yolov8/platform_detection/SGD_full_dataset/weights/best.pt")

# model.predict(source="/home/msccomputer/Desktop/test.png", save=True, iou=0.4) # Display preds. Accepts all YOLO predict arguments


model.predict(source="/home/msccomputer/catkin_ws/src/msc_thesis/offline_utils/train_yolov8/Platform-3/test/images", save=True, iou=0.1) # Display preds. Accepts all YOLO predict arguments
# Out:
# Ultralytics YOLOv8.0.36 🚀 Python-3.8.10 torch-1.13.1+cu117 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 7982MiB)
# YOLOv8n summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/206 /home/msccomputer/catkin_ws/src/msc_thesis/offline_utils/train_yolov8/Platform-3/test/images/GF_dark_stonefloor_12_png.rf.9f91cef1f75581b3faac034aa102266f.jpg: 736x1280 1 platform, 10.4ms
# image 2/206 /home/msccomputer/catkin_ws/src/msc_thesis/offline_utils/train_yolov8/Platform-3/test/images/GF_dark_stonefloor_33_png.rf.c78cdc8bf06376e8fdb62e3fd4746f9b.jpg: 736x1280 1 platform, 9.5ms
# image 3/206 /home/msccomputer/catkin_ws/src/msc_thesis/offline_utils/train_yolov8/Platform-3/test/images/GF_dark_stonefloor_44_png.rf.188dca5bd97d4b40fe633962d6aaeb1d.jpg: 736x1280 1 platform, 9.4ms
# ...
